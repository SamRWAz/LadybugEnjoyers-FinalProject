# %% [markdown]
# # 01 — Análisis Exploratorio de Datos
#
# LadybugEnjoyers — Clasificación de calidad de frutas
#
# Ejecutar primero: `python -m src.main --step data`

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display

manifest = pd.read_csv(ROOT / 'data/processed/manifest.csv')
manifest.head()

# %%
print('Total imágenes:', len(manifest))
print(manifest['quality'].value_counts())
print(manifest['fruit_type'].value_counts().head(10))

# %%
from src.evaluation.eda import run_eda
run_eda()
display(Image(filename=str(ROOT / 'experiments/results/eda_class_distribution.png')))
display(Image(filename=str(ROOT / 'experiments/results/eda_size_by_quality.png')))
